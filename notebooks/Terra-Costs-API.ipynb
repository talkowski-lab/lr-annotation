# %% [markdown]
# # Setup

# %%
# workspace_namespace = "broad-firecloud-dsde-methods"
# workspace_name = "kj-rdtest-test"
# submission_ids = ["e0160046-238e-479e-ab74-35d8f4d799e3"]

# %%
workspace_namespace = "talk-LR-gnomADLR_supplement" # @param {type:"string"}
workspace_name = "gnomAD_LR_CNV_benchmarking" # @param {type:"string"}
submission_ids = ["f0d718a2-b3e1-4c92-b40d-51d5c8835f07"] # @param {type:"raw"}

# %%
import subprocess
import requests
import pandas as pd

# %%
oauth_token = subprocess.check_output("gcloud auth print-access-token", shell=True, text=True).strip()

authorization_token = oauth_token

headers = {
    'Authorization': f'Bearer {authorization_token}',
    'Content-Type': 'application/json',
}

# %% [markdown]
# # Get submission details

# %%
rows = []
for sub_id in submission_ids:
    endpoint = f"https://api.firecloud.org/api/workspaces/{workspace_namespace}/{workspace_name}/submissions/{sub_id}"
    submission_details = requests.get(endpoint, headers=headers).json()
    print(submission_details)

    for workflow in submission_details["workflows"]:
        entity = workflow.get("workflowEntity", {})
        rows.append({
            "submissionId": sub_id,
            "methodConfigurationName": submission_details["methodConfigurationName"],
            "workflowId": workflow["workflowId"],
            "status": workflow["status"],
            "cost": workflow.get("cost"),
            "costType": workflow.get("costType"),
            "entityType": entity.get("entityType"),
            "entityName": entity.get("entityName"),
        })

pd.DataFrame(rows)
# Out:
# {'cost': 0.0, 'deleteIntermediateOutputFiles': True, 'ignoreEmptyOutputs': False, 'memoryRetryMultiplier': 1.0, 'methodConfigurationName': 'MosDepth_bEXi8fM0Z4w', 'methodConfigurationNamespace': 'talk-LR-gnomADLR_supplement', 'perWorkflowCostCap': 10.0, 'status': 'Done', 'submissionDate': '2026-07-30T14:58:15.221Z', 'submissionEntity': {'entityType': 'LR_sample_full_set', 'entityName': 'MosDepth_2026-07-30T14-56-47__l_7PxhEi6j7QJQ'}, 'submissionId': 'f0d718a2-b3e1-4c92-b40d-51d5c8835f07', 'submissionRoot': 'gs://fc-a4fb87f2-6cf2-4b8c-82fc-0dc93c5c6837/submissions/f0d718a2-b3e1-4c92-b40d-51d5c8835f07', 'submitter': 'kjaising@broadinstitute.org', 'useCallCache': True, 'useReferenceDisks': False, 'userComment': '1 CPU, per-base, single contig, no -x ($0.00)', 'workflows': [{'cost': 0.0, 'costType': 'Actual', 'inputResolutions': [{'inputName': 'MosDepth.bai', 'value': 'gs://fc-50f5097c-c1b5-4611-9f49-ce88d43f76c7/methylation/HG002.GRCh38.haplotagged.bam.bai'}, {'inputName': 'MosDepth.bam', 'value': 'gs://fc-50f5097c-c1b5-4611-9f49-ce88d43f76c7/methylation/HG002.GRCh38.haplotagged.bam'}, {'inputName': 'MosDepth.contigs', 'value': ['chr1', 'chr2', 'chr3', 'chr4', 'chr5', 'chr6', 'chr7', 'chr8', 'chr9', 'chr10', 'chr11', 'chr12', 'chr13', 'chr14', 'chr15', 'chr16', 'chr17', 'chr18', 'chr19', 'chr20', 'chr21', 'chr22', 'chrX', 'chrY']}, {'inputName': 'MosDepth.fast_mode', 'value': False}, {'inputName': 'MosDepth.mosdepth_docker', 'value': 'us-central1-docker.pkg.dev/talkowski-sv-gnomad/kj-dockers/mosdepth:latest'}, {'inputName': 'MosDepth.prefix', 'value': 'HG002'}, {'inputName': 'MosDepth.runtime_attr_run_mosdepth', 'value': {}}, {'inputName': 'MosDepth.single_contig', 'value': True}], 'messages': [], 'status': 'Succeeded', 'statusLastChangedDate': '2026-07-30T22:26:08.795Z', 'workflowEntity': {'entityType': 'LR_sample_full', 'entityName': 'HG002'}, 'workflowId': '84c960f6-d0f9-4a12-968f-af32349ceaa6'}, {'cost': 0.0, 'costType': 'Actual', 'inputResolutions': [{'inputName': 'MosDepth.bai', 'value': 'gs://fc-7f861a33-ddb4-4b2f-8d10-5679c9df6108/submissions/47e79f08-7774-4ce0-b714-4d49d1386191/MapCCSPhase2/95bd633b-00f3-42da-905b-734e7c79ed3f/call-MapCCSImpl/HG00733.bam.bai'}, {'inputName': 'MosDepth.bam', 'value': 'gs://fc-7f861a33-ddb4-4b2f-8d10-5679c9df6108/submissions/47e79f08-7774-4ce0-b714-4d49d1386191/MapCCSPhase2/95bd633b-00f3-42da-905b-734e7c79ed3f/call-MapCCSImpl/HG00733.bam'}, {'inputName': 'MosDepth.contigs', 'value': ['chr1', 'chr2', 'chr3', 'chr4', 'chr5', 'chr6', 'chr7', 'chr8', 'chr9', 'chr10', 'chr11', 'chr12', 'chr13', 'chr14', 'chr15', 'chr16', 'chr17', 'chr18', 'chr19', 'chr20', 'chr21', 'chr22', 'chrX', 'chrY']}, {'inputName': 'MosDepth.fast_mode', 'value': False}, {'inputName': 'MosDepth.mosdepth_docker', 'value': 'us-central1-docker.pkg.dev/talkowski-sv-gnomad/kj-dockers/mosdepth:latest'}, {'inputName': 'MosDepth.prefix', 'value': 'HG00733'}, {'inputName': 'MosDepth.runtime_attr_run_mosdepth', 'value': {}}, {'inputName': 'MosDepth.single_contig', 'value': True}], 'messages': [], 'status': 'Succeeded', 'statusLastChangedDate': '2026-07-30T22:01:40.592Z', 'workflowEntity': {'entityType': 'LR_sample_full', 'entityName': 'HG00733'}, 'workflowId': '2ab9dba4-04a7-411b-9ab0-cb0cfa9bacda'}, {'cost': 0.0, 'costType': 'Actual', 'inputResolutions': [{'inputName': 'MosDepth.bai', 'value': 'gs://fc-7f861a33-ddb4-4b2f-8d10-5679c9df6108/submissions/23fc19f8-d526-48aa-9068-bcc2a2925c34/MapCCSPhase2/9852a8dc-a0fc-4be4-9693-1e4329ac0a19/call-MapCCSImpl/HG02818.bam.bai'}, {'inputName': 'MosDepth.bam', 'value': 'gs://fc-7f861a33-ddb4-4b2f-8d10-5679c9df6108/submissions/23fc19f8-d526-48aa-9068-bcc2a2925c34/MapCCSPhase2/9852a8dc-a0fc-4be4-9693-1e4329ac0a19/call-MapCCSImpl/HG02818.bam'}, {'inputName': 'MosDepth.contigs', 'value': ['chr1', 'chr2', 'chr3', 'chr4', 'chr5', 'chr6', 'chr7', 'chr8', 'chr9', 'chr10', 'chr11', 'chr12', 'chr13', 'chr14', 'chr15', 'chr16', 'chr17', 'chr18', 'chr19', 'chr20', 'chr21', 'chr22', 'chrX', 'chrY']}, {'i ...
#                            submissionId methodConfigurationName  \
# 0  f0d718a2-b3e1-4c92-b40d-51d5c8835f07    MosDepth_bEXi8fM0Z4w
# 1  f0d718a2-b3e1-4c92-b40d-51d5c8835f07    MosDepth_bEXi8fM0Z4w
# 2  f0d718a2-b3e1-4c92-b40d-51d5c8835f07    MosDepth_bEXi8fM0Z4w
# 3  f0d718a2-b3e1-4c92-b40d-51d5c8835f07    MosDepth_bEXi8fM0Z4w
# 4  f0d718a2-b3e1-4c92-b40d-51d5c8835f07    MosDepth_bEXi8fM0Z4w
#
#                              workflowId     status  cost costType  \
# 0  84c960f6-d0f9-4a12-968f-af32349ceaa6  Succeeded   0.0   Actual
# 1  2ab9dba4-04a7-411b-9ab0-cb0cfa9bacda  Succeeded   0.0   Actual
# 2  5cd457d8-00b4-4374-a425-b86b08b220ed  Succeeded   0.0   Actual
# 3  c34805fd-7219-405b-b5c7-6b19799467d1  Succeeded   0.0   Actual
# 4  35ed5d6c-75ce-44f3-b4c7-715ced0eb592  Succeeded   0.0   Actual
#
#        entityType entityName
# 0  LR_sample_full      HG002
# 1  LR_sample_full    HG00733
# 2  LR_sample_full    HG02818
# 3  LR_sample_full    NA19036
# 4  LR_sample_full    NA19240
